# %% [markdown]
# <a href="https://colab.research.google.com/github/mich-j/BHL2022/blob/main/visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Optoelektronika :C

# %%
import pandas as pd
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %cd /content

dd = pd.read_csv('IpdF_UpdF_2022-12-02_16-24-39_0.csv', sep=',', skiprows=3)
data_table.DataTable(dd)
# Out:
# /content
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Time</th>
#       <th>Step</th>
#       <th>Set CH1 On/Off</th>
#       <th>Set CH2 On/Off</th>
#       <th>Sweep CH2 Voltage Setting</th>
#       <th>Get CH2 Voltage Setting</th>
#       <th>Get CH2 Current Measurement</th>
#       <th>Sweep CH1 Voltage Setting</th>
#       <th>Get Measurement Value</th>
#       <th>Get Measurement Value.1</th>
#       <th>Set CH1 On/Off.1</th>
#       <th>Set CH2 On/Off ()</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2022-12-02 16:12:08.494</td>
#       <td>1</td>
#       <td>1.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...
